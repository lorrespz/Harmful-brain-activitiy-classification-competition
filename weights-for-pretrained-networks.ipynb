# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Inception Network pretrained weights

# %%
from tensorflow.keras.applications import InceptionV3

# %%
IncV3 = InceptionV3(include_top = False, weights = 'imagenet', input_shape = None)
# Out:
# ...
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
IncV3.save_weights('InceptionV3_imagenet_weights.h5')

# %% [markdown]
# # InceptionResNetV2

# %%
#https://www.tensorflow.org/api_docs/python/tf/keras/applications/inception_resnet_v2
from tensorflow.keras.applications import InceptionResNetV2
# Out:
# 2024-02-09 08:36:54.203633: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-09 08:36:54.203850: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-09 08:36:54.389245: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
IncRes = InceptionResNetV2(include_top = False, weights = 'imagenet', input_shape = None)
# Out:
# ...
# 219055592/219055592 [==============================] - 2s 0us/step

# %%
IncRes.save_weights('InceptionResNetV2_imagenet_weights.h5')

# %% [markdown]
# # EfficientNetB0 pretrained weights

# %%
from tensorflow.keras.applications import EfficientNetB0

# %%
EffNetB0 = EfficientNetB0(include_top=False, weights = 'imagenet', input_shape=None)
# Out:
# ...
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
EffNetB0.save_weights('EfficientNetB0_imagenet_weights.h5')

# %% [markdown]
# # MobileNet pretrained weights

# %%
#https://stackoverflow.com/questions/60930766/tensorflow-use-pretrained-model-in-offline
from tensorflow.keras.applications import MobileNetV2

# %%
MobNetV2 =  MobileNetV2(include_top=False, weights = 'imagenet', input_shape=None)
# Out:
# ...
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
MobNetV2.save_weights('MobileNetV2_imagenet_weights.h5')

# %% [markdown]
# # VGG16 pretrained weights

# %%
from tensorflow.keras.applications import VGG16

# %%
vgg16 =  VGG16(include_top=False, weights = 'imagenet', input_shape=None)
# Out:
# ...
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
vgg16.save_weights('vgg16_imagenet_weights.h5')
